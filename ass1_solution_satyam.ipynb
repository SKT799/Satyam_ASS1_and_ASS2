# %%
#Clone the Dataset
from datasets import load_dataset
dataset = load_dataset("ainlpml/english-hindi")
# Out:
# README.md:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# eng.txt:   0%|          | 0.00/1.01M [00:00<?, ?B/s]
# hin.txt:   0%|          | 0.00/2.45M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/20000 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 20000
#     })
# })

# %%
dataset['train'][0:5]
# Out:
# {'text': ["However, Paes, who was partnering Australia's Paul Hanley, could only go as far as the quarterfinals where they lost to Bhupathi and Knowles ",
#   'Whosoever desires the reward of the world, with Allah is the reward of the world and of the Everlasting Life. Allah is the Hearer, the Seer. ',
#   '"The value of insects in the biosphere is enormous because they outnumber all other living groups in measure of species richness. ',
#   'Mithali To Anchor Indian Team Against Australia in ODIs ',
#   'After the assent of the Honble President on 8thSeptember, 2016, the 101thConstitutional Amendment Act, 2016 came into existence ']}

# %%
import pandas as pd

# %%
# Load the Data into Google Sheets
df = pd.DataFrame(dataset['train'])
df.head()
# Out:
#                                                 text
# 0  However, Paes, who was partnering Australia's ...
# 1  Whosoever desires the reward of the world, wit...
# 2  "The value of insects in the biosphere is enor...
# 3  Mithali To Anchor Indian Team Against Australi...
# 4  After the assent of the Honble President on 8t...

# %%
df
# Out:
#                                                     text
# 0      However, Paes, who was partnering Australia's ...
# 1      Whosoever desires the reward of the world, wit...
# 2      "The value of insects in the biosphere is enor...
# 3      Mithali To Anchor Indian Team Against Australi...
# 4      After the assent of the Honble President on 8t...
# ...                                                  ...
# 19995  इन चंद, चुनिंदा शब्दों से बुद्धिमान राजा सुलैम...
# 19996  पुलिस ने युवकों का पीछा कर दो युवकों को हिरासत...
# 19997  में मुर्गीपालन से प्राप्त मांस तथा गाद का अनुम...
# 19998  सबसे पहले ऑफिशियल वेबसाइट education. rajasthan...
# 19999  डिस्क्लेमर : अनिल अंबानी के रिलायंस ग्रुप ने N...
#
# [20000 rows x 1 columns]

# %%
# Hindi and English Dataset spliting:
midpoint =len(df)//2
# midpoint

english_data = df['text'].iloc[:midpoint].reset_index(drop=True)
# english_data

hindi_data = df['text'].iloc[midpoint:].reset_index(drop=True)
# hindi_data

processed_df = pd.DataFrame({
    #coloum1
    'English Sentences':english_data,

    #coloum2
    'Hindi Sentences':hindi_data
}
)

processed_df
# Out:
#                                       English Sentences  \
# 0     However, Paes, who was partnering Australia's ...
# 1     Whosoever desires the reward of the world, wit...
# 2     "The value of insects in the biosphere is enor...
# 3     Mithali To Anchor Indian Team Against Australi...
# 4     After the assent of the Honble President on 8t...
# ...                                                 ...
# 9995  With these few, well - chosen words, wise King...
# 9996  Police have arrested two people and apprehende...
# 9997  "The annual production of poultry meat in 1991...
# 9998  Step 1: Visit the official websites rsosapp.ra...
# 9999  Anil Ambanis Reliance Group has sued news chan...
#
#                                         Hindi Sentences
# 0     आस्ट्रेलिया के पाल हेनली के साथ जोड़ी बनाने वाल...
# 1     और जो शख्स (अपने आमाल का) बदला दुनिया ही में च...
# 2     जैव-मंडल में कीड़ों का मूल्य बहुत है, क्योंकि ...
# 3      आस्ट्रेलिया के खिलाफ वनडे टीम की कमान मिताली को
# 4     8 सितम्‍बर, 2016 को माननीय राष्‍ट्रपति की स्‍व...
# ...                                                 ...
# 9995  इन चंद, चुनिंदा शब्दों से बुद्धिमान राजा सुलैम...
# 9996  पुलिस ने युवकों का पीछा कर दो युवकों को हिरासत...
# 9997  में मुर्गीपालन से प्राप्त मांस तथा गाद का अनुम...
# 9998  सबसे पहले ऑफिशियल वेबसाइट education. rajasthan...
# 9999  डिस्क्लेमर : अनिल अंबानी के रिलायंस ग्रुप ने N...
#
# [10000 rows x 2 columns]

# %%
# Keep only those words count whose sentences fall within the range of 5 to 50 in both languages.

#count english:
processed_df['Word Count(English)'] = processed_df['English Sentences'].astype(str).str.split().str.len()



#count hindi:
processed_df['Word Count(Hindi)'] = processed_df['Hindi Sentences'].astype(str).str.split().str.len()


# processed_df

#Filter English:
processed_df = processed_df[(processed_df['Word Count(English)']>=5) & (processed_df['Word Count(English)'] <=50)]

#Filter Hindi:
processed_df = processed_df[(processed_df['Word Count(Hindi)']>=5) & (processed_df['Word Count(Hindi)'] <=50)]

processed_df
# Out:
# /tmp/ipykernel_16964/2843562492.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processed_df['Word Count(English)'] = processed_df['English Sentences'].astype(str).str.split().str.len()
# /tmp/ipykernel_16964/2843562492.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processed_df['Word Count(Hindi)'] = processed_df['Hindi Sentences'].astype(str).str.split().str.len()
#                                       English Sentences  \
# 0     However, Paes, who was partnering Australia's ...
# 1     Whosoever desires the reward of the world, wit...
# 2     "The value of insects in the biosphere is enor...
# 3     Mithali To Anchor Indian Team Against Australi...
# 4     After the assent of the Honble President on 8t...
# ...                                                 ...
# 9995  With these few, well - chosen words, wise King...
# 9996  Police have arrested two people and apprehende...
# 9997  "The annual production of poultry meat in 1991...
# 9998  Step 1: Visit the official websites rsosapp.ra...
# 9999  Anil Ambanis Reliance Group has sued news chan...
#
#                                         Hindi Sentences  Word Count(English)  \
# 0     आस्ट्रेलिया के पाल हेनली के साथ जोड़ी बनाने वाल...                   23
# 1     और जो शख्स (अपने आमाल का) बदला दुनिया ही में च...                   26
# 2     जैव-मंडल में कीड़ों का मूल्य बहुत है, क्योंकि ...                   21
# 3      आस्ट्रेलिया के खिलाफ वनडे टीम की कमान मिताली को                     9
# 4     8 सितम्‍बर, 2016 को माननीय राष्‍ट्रपति की स्‍व...                   18
# ...                                                 ...                  ...
# 9995  इन चंद, चुनिंदा शब्दों से बुद्धिमान राजा सुलैम...                   30
# 9996  पुलिस ने युवकों का पीछा कर दो युवकों को हिरासत...                   10
# 9997  में मुर्गीपालन से प्राप्त मांस तथा गाद का अनुम...                   24
# 9998  सबसे पहले ऑफिशियल वेबसाइट education. rajasthan...                    9
# 9999  डिस्क्लेमर : अनिल अंबानी के रिलायंस ग्रुप ने N...                   27
#
#       Word Count(Hindi)
# 0                    28
# 1                    35
# 2                    22
# 3                     9
# 4                    19
# ...                 ...
# 9995                 38
# 9996                 14
# 9997                 24
# 9998                 10
# 9999                 23
#
# [8788 rows x 4 columns]

# %%
# Retain only those word pairs where the word count difference lies within the range of -10 to +10.

processed_df['Difference between Word Count(English) and Word Count(Hindi)'] = processed_df['Word Count(English)'] - processed_df['Word Count(Hindi)']


processed_df = processed_df[(processed_df['Difference between Word Count(English) and Word Count(Hindi)']>=-10) & (processed_df['Difference between Word Count(English) and Word Count(Hindi)']<=10)]

processed_df
# Out:
# /tmp/ipykernel_16964/2649733901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   processed_df['Difference between Word Count(English) and Word Count(Hindi)'] = processed_df['Word Count(English)'] - processed_df['Word Count(Hindi)']
#                                       English Sentences  \
# 0     However, Paes, who was partnering Australia's ...
# 1     Whosoever desires the reward of the world, wit...
# 2     "The value of insects in the biosphere is enor...
# 3     Mithali To Anchor Indian Team Against Australi...
# 4     After the assent of the Honble President on 8t...
# ...                                                 ...
# 9995  With these few, well - chosen words, wise King...
# 9996  Police have arrested two people and apprehende...
# 9997  "The annual production of poultry meat in 1991...
# 9998  Step 1: Visit the official websites rsosapp.ra...
# 9999  Anil Ambanis Reliance Group has sued news chan...
#
#                                         Hindi Sentences  Word Count(English)  \
# 0     आस्ट्रेलिया के पाल हेनली के साथ जोड़ी बनाने वाल...                   23
# 1     और जो शख्स (अपने आमाल का) बदला दुनिया ही में च...                   26
# 2     जैव-मंडल में कीड़ों का मूल्य बहुत है, क्योंकि ...                   21
# 3      आस्ट्रेलिया के खिलाफ वनडे टीम की कमान मिताली को                     9
# 4     8 सितम्‍बर, 2016 को माननीय राष्‍ट्रपति की स्‍व...                   18
# ...                                                 ...                  ...
# 9995  इन चंद, चुनिंदा शब्दों से बुद्धिमान राजा सुलैम...                   30
# 9996  पुलिस ने युवकों का पीछा कर दो युवकों को हिरासत...                   10
# 9997  में मुर्गीपालन से प्राप्त मांस तथा गाद का अनुम...                   24
# 9998  सबसे पहले ऑफिशियल वेबसाइट education. rajasthan...                    9
# 9999  डिस्क्लेमर : अनिल अंबानी के रिलायंस ग्रुप ने N...                   27
#
#       Word Count(Hindi)  \
# 0                    28
# 1                    35
# 2                    22
# 3                     9
# 4                    19
# ...                 ...
# 9995                 38
# 9996                 14
# 9997                 24
# 9998                 10
# 9999                 23
#
#       Difference between Word Count(English) and Word Count(Hindi)
# 0                                                    -5
# 1                                                    -9
# 2                                                    -1
# 3                                                     0
# 4                                                    -1
# ...                                                 ...
# 9995                                                 -8
# 9996                                                 -4
# 9997                                                  0
# 9998                                                 -1
# 9999                                                  4
#
# [8214 rows x 5 columns]

# %%
# Final Output:
'''
English Sentences
Hindi Sentences
Word Count (English)
Word Count (Hindi)
Difference between Word Count (English) and Word Count (Hindi)

'''

final_coloums =[
    'English Sentences',
    'Hindi Sentences',
    'Word Count(English)',
    'Word Count(Hindi)',
    'Difference between Word Count(English) and Word Count(Hindi)'
]

final_df = processed_df[final_coloums]
# final_df

final_df.to_excel("iitp_nlp_satyam.xlsx")
